# %%
import pandas as pd
df_sales=pd.read_excel("Sales_Dataset_Part1 (1).xlsx")
df_sales
# Out:
#    Order_ID  Order_Date Product_Name     Category  Quantity  Unit_Price  \
# 0    ORD001  01-01-2026       Laptop  Electronics         2       50000
# 1    ORD002  01-01-2026        Mouse  Accessories         5         800
# 2    ORD003  02-01-2026     Keyboard  Accessories         3        1500
# 3    ORD004  02-01-2026      Monitor  Electronics         2       12000
# 4    ORD005  03-01-2026      Printer  Electronics         1       15000
# 5    ORD006  03-01-2026    USB Drive  Accessories        10         700
# 6    ORD007  04-01-2026   Smartphone  Electronics         4       25000
# 7    ORD008  04-01-2026   Headphones  Accessories         6        2500
# 8    ORD009  05-01-2026       Webcam  Accessories         3        3000
# 9    ORD010  05-01-2026       Tablet  Electronics         2       20000
# 10   ORD011  06-01-2026       Laptop  Electronics         1       50000
# 11   ORD012  06-01-2026        Mouse  Accessories         8         800
# 12   ORD013  07-01-2026     Keyboard  Accessories         4        1500
# 13   ORD014  07-01-2026      Printer  Electronics         2       15000
# 14   ORD015  08-01-2026   Smartphone  Electronics         3       25000
# 15   ORD016  08-01-2026      Monitor  Electronics         2       12000
# 16   ORD017  09-01-2026    USB Drive  Accessories        12         700
# 17   ORD018  09-01-2026       Tablet  Electronics         1       20000
# 18   ORD019  10-01-2026   Headphones  Accessories         5        2500
# 19   ORD020  10-01-2026       Webcam  Accessories         2        3000
# 20   ORD021  11-01-2026       Laptop  Electronics         2       50000
# 21   ORD022  11-01-2026   Smartphone  Electronics         2       25000
# 22   ORD023  12-01-2026     Keyboard  Accessories         5        1500
# 23   ORD024  12-01-2026      Monitor  Electronics         1       12000
# 24   ORD025  13-01-2026      Printer  Electronics         2       15000
#
#     Total_Sales Payment_Mode Region
# 0        100000          UPI  South
# 1          4000         Cash  North
# 2          4500         Card   East
# 3         24000          UPI   West
# 4         15000         Card  South
# 5          7000         Cash  North
# 6        100000          UPI   East
# 7         15000         Card   West
# 8          9000          UPI  South
# 9         40000         Cash  North
# 10        50000         Card   East
# 11         6400          UPI   West
# 12         6000         Cash  South
# 13        30000         Card  North
# 14        75000          UPI   East
# 15        24000         Cash   West
# 16         8400         Card  South
# 17        20000          UPI  North
# 18        12500         Cash   East
# 19         6000         Card   West
# 20       100000          UPI  South
# 21        50000         Cash  North
# 22         7500         Card   East
# 23        12000          UPI   West
# 24        30000         Cash  South

# %%
print(df.info())

print(df.describe())

print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      25 non-null     object
#  1   Order_Date    25 non-null     datetime64[ns]
#  2   Product_Name  25 non-null     object
#  3   Category      25 non-null     object
#  4   Quantity      25 non-null     int64
#  5   Unit_Price    25 non-null     int64
#  6   Total_Sales   25 non-null     int64
#  7   Payment_Mode  25 non-null     object
#  8   Region        25 non-null     object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 1.9+ KB
# None
#                 Order_Date  Quantity    Unit_Price    Total_Sales
# count                   25  25.00000     25.000000      25.000000
# mean   2026-01-06 18:14:24   3.60000  14580.000000   30252.000000
# min    2026-01-01 00:00:00   1.00000    700.000000    4000.000000
# 25%    2026-01-04 00:00:00   2.00000   1500.000000    7500.000000
# 50%    2026-01-07 00:00:00   2.00000  12000.000000   15000.000000
# 75%    2026-01-10 00:00:00   5.00000  20000.000000   40000.000000
# max    2026-01-13 00:00:00  12.00000  50000.000000  100000.000000
# std                    NaN   2.84312  15820.740606   31526.234049
# Order_ID        0
# Order_Date      0
# Product_Name    0
# Category        0
# Quantity        0
# Unit_Price      0
# Total_Sales     0
# Payment_Mode    0
# Region          0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

df["Order_Date"] = pd.to_datetime(df["Order_Date"], format="%d-%m-%Y")

df["Quantity"] = pd.to_numeric(df["Quantity"])

df["Unit_Price"] = pd.to_numeric(df["Unit_Price"])

df["Total_Sales"] = pd.to_numeric(df["Total_Sales"])

# %%
total_sales = df["Total_Sales"].sum()

print("Total Sales =", total_sales)
# Out:
# Total Sales = 756300

# %%
category_sales = df.groupby("Category")["Total_Sales"].sum()

print(category_sales)
# Out:
# Category
# Accessories     86300
# Electronics    670000
# Name: Total_Sales, dtype: int64

# %%
product_sales = df.groupby("Product_Name")["Total_Sales"].sum()

print(product_sales)
# Out:
# Product_Name
# Headphones     27500
# Keyboard       18000
# Laptop        250000
# Monitor        60000
# Mouse          10400
# Printer        75000
# Smartphone    225000
# Tablet         60000
# USB Drive      15400
# Webcam         15000
# Name: Total_Sales, dtype: int64

# %%
region_sales = df.groupby("Region")["Total_Sales"].sum()

print(region_sales)
# Out:
# Region
# East     249500
# North    151000
# South    268400
# West      87400
# Name: Total_Sales, dtype: int64

# %%
payment = df["Payment_Mode"].value_counts()

print(payment)
# Out:
# Payment_Mode
# UPI     9
# Cash    8
# Card    8
# Name: count, dtype: int64

# %%
category_sales.plot(kind="pie", autopct="%1.1f%%")

plt.title("Category-wise Sales")

plt.ylabel("")

plt.show()

# %%
product_sales.plot(kind="bar", figsize=(10,5))

plt.title("Product-wise Sales")

plt.xlabel("Products")

plt.ylabel("Sales")

plt.show()

# %%
region_sales.plot(kind="bar", figsize=(8,5))

plt.title("Region-wise Sales")

plt.xlabel("Region")

plt.ylabel("Sales")

plt.show()

# %%
print("========== SALES & REVENUE ANALYSIS REPORT ==========")

print("Total Sales:", total_sales)

print("Highest Revenue Category:", category_sales.idxmax())

print("Top Selling Product:", product_sales.idxmax())

print("Best Performing Region:", region_sales.idxmax())

print("Most Used Payment Mode:", payment.idxmax())
# Out:
# ========== SALES & REVENUE ANALYSIS REPORT ==========
# Total Sales: 756300
# Highest Revenue Category: Electronics
# Top Selling Product: Laptop
# Best Performing Region: South
# Most Used Payment Mode: UPI

# %%
df.to_excel("clean_sales_data.xlsx", index=False)

print("Cleaned dataset exported successfully.")
# Out:
# Cleaned dataset exported successfully.

# %%
df.to_excel("cleaned_sales_data.xlsx", index=False)

# %%
from google.colab import files
files.download("cleaned_sales_data.xlsx")
